# %% [markdown]
# ### 1. Rating Drivers

# %% [markdown]
# Features:
# accords,
# notes,
# gender,
# release_year,
# price_value,
# longevity,
# sillage

# %% [markdown]
# ### 2. NLP

# %% [markdown]
# Use TF-IDF to identify most important fragrance descriptors.

# %% [markdown]
# ### 3. Recommendation System

# %% [markdown]
# User to input keywords, Recommendation system to recommend perfumes according to keywords.

# %% [markdown]
# ### 4. Community Behavior

# %% [markdown]
# Vote distributions, which notes drive longevity?

# %% [markdown]
# ### 5. Clustering

# %% [markdown]
# Create a fragrance map
